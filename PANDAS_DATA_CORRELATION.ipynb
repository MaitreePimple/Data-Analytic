# %% [markdown]
# <a href="https://colab.research.google.com/github/MaitreePimple/Data-Analytic/blob/main/PANDAS_DATA_CORRELATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Correlation -> an statistical relationship between 2 or more variables

# %% [markdown]
# FINDING RELATIONSHIP
#
#
# >-> in pandas great ascept is  PANDAS MODULE corr() method
#
# >-> corr() method calculates the realtionship bwt each col in data set
#
#
# >-> corr() method ignores not numeric columns

# %%
import pandas as pd
df=pd.read_csv("data.csv")
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# -> to see how good relationship is there btw 2 variables number varies btw -1 to 1
#
#
# > as number increases the value also increase like 0.9 is good also -0.9 is good
#
#
# > 0.2 is not good

# %% [markdown]
# WHAT IS GOOD CORRELATION?
# ->It depends on us , but I think theat safe is atleast 0.6 or -0.6
#
#
# > Perfect correlation -> eg: 1.000000
#
# > Good correlation -> eg:0.9
