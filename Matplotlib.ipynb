# %% [markdown]
# <a href="https://colab.research.google.com/github/MaitreePimple/Data-Analytic/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MATPLOTLIB
#
#
# > Its an low level graph plotting library in python and its opens source and be used freely

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# **Matplotlin Pyplot**
#
#
# > most of matplotlin utilies lies under pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2,8])
y = np.array([2,7])

plt.plot(x,y)
plt.show()
